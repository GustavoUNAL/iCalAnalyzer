# %%
import caldav
from datetime import datetime, timedelta

# Conectar a iCloud
url = "https://caldav.icloud.com"
username = "gustavoarteaga0508@gmail.com"
password = "rbmh-lbha-cwci-lmaf"

client = caldav.DAVClient(url=url, username=username, password=password)
principal = client.principal()

# Obtener calendarios
calendars = principal.calendars()
# Imprimir información de cada calendario
print("\n=== INFORMACIÓN DE TODOS LOS CALENDARIOS ===")
for i, calendar in enumerate(calendars):
    print(f"\nCalendario {i+1}:")
    print(f"Nombre: {calendar.name}")
    print(f"URL: {calendar.url}")
    print(f"ID: {calendar.id}")
    
    # Obtener todos los eventos del calendario
    print("\nEventos:")
    try:
        # Obtener eventos desde hace un año hasta un año en el futuro
        start_date = datetime.now() - timedelta(days=7)
        end_date = datetime.now() + timedelta(days=7)
        
        events = calendar.date_search(
            start=start_date,
            end=end_date
        )
        
        if not events:
            print("No hay eventos en este calendario")
        
        for j, event in enumerate(events):
            print(f"\nEvento {j+1}:")
            try:
                # Intentar obtener propiedades específicas del evento
                event_data = event.instance.vevent
                print(f"Título: {event_data.summary.value if hasattr(event_data, 'summary') else 'Sin título'}")
                print(f"Inicio: {event_data.dtstart.value if hasattr(event_data, 'dtstart') else 'Sin fecha de inicio'}")
                print(f"Fin: {event_data.dtend.value if hasattr(event_data, 'dtend') else 'Sin fecha de fin'}")
                print(f"Ubicación: {event_data.location.value if hasattr(event_data, 'location') else 'Sin ubicación'}")
                print(f"Descripción: {event_data.description.value if hasattr(event_data, 'description') else 'Sin descripción'}")
            except Exception as e:
                print(f"Error al procesar evento: {str(e)}")
                print("Datos raw del evento:")
                print(event.data)
                
    except Exception as e:
        print(f"Error al obtener eventos: {str(e)}")

print("\n=== FIN DEL REPORTE ===")
# Out:
# === INFORMACIÓN DE TODOS LOS CALENDARIOS ===
#
# Calendario 1:
# Nombre: VLESIM ®️
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/226EFBB7-8B3C-40E0-97C6-4A82033B1657/
# ID: 226EFBB7-8B3C-40E0-97C6-4A82033B1657
#
# Eventos:
#
# Evento 1:
# Título: Almuerzo
# Inicio: 2025-01-19 14:00:00-05:00
# Fin: 2025-01-19 16:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 2:
# Título: Reuniones
# Inicio: 2025-01-20 09:30:00-05:00
# Fin: 2025-01-20 12:30:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 3:
# Título: Weekly letter
# Inicio: 2025-01-20 14:00:00-05:00
# Fin: 2025-01-20 15:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 4:
# Título: Reunión manillas
# Inicio: 2025-01-20 16:00:00-05:00
# Fin: 2025-01-20 17:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 5:
# Título: Reunión finanzas
# Inicio: 2025-01-20 17:00:00-05:00
# Fin: 2025-01-20 18:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 2:
# Nombre: Personal
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/2F8CF266-FE40-4A7D-9499-0BDD0608DA95/
# ID: 2F8CF266-FE40-4A7D-9499-0BDD0608DA95
#
# Eventos:
#
# Evento 1:
# Título: Perros
# Inicio: 2025-01-19 21:00:00-05:00
# Fin: 2025-01-19 23:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 2:
# Título: Perros
# Inicio: 2025-01-20 19:00:00-05:00
# Fin: 2025-01-20 21:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 3:
# Nombre: Reminders ⚠️
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/38ace0be-bff9-4739-8515-b198f455fd9a/
# ID: 38ace0be-bff9-4739-8515-b198f455fd9a
#
# Eventos:
# No hay eventos en este calendario
#
# Calendario 4:
# Nombre: Health 🩻
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/4199545E-C4EE-420B-9FF7-A7203C788984/
# ID: 4199545E-C4EE-420B-9FF7-A7203C788984
#
# Eventos:
#
# Evento 1:
# Título: Gym
# Inicio: 2025-01-19 12:00:00-05:00
# Fin: 2025-01-19 14:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 5:
# Nombre: Sleep
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/8B59E2B0-A7C0-4DA0-B678-40B21DF8FD20/
# ID: 8B59E2B0-A7C0-4DA0-B678-40B21DF8FD20
#
# Eventos:
#
# Evento 1:
# Título: Estados Unidos
# Inicio: 2025-01-19 23:30:00-05:00
# Fin: 2025-01-20 09:30:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 6:
# Nombre: Transporte
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/9025349A-4047-43B2-8357-D1339124332A/
# ID: 9025349A-4047-43B2-8357-D1339124332A
#
# Eventos:
#
# Evento 1:
# Título: Camino u
# Inicio: 2025-01-20 13:30:00-05:00
# Fin: 2025-01-20 14:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 7:
# Nombre: Eat
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/9A8A3FD7-C30B-491A-97D4-A78D2E39523E/
# ID: 9A8A3FD7-C30B-491A-97D4-A78D2E39523E
#
# Eventos:
#
# Evento 1:
# Título: Almuerzo
# Inicio: 2025-01-20 12:30:00-05:00
# Fin: 2025-01-20 13:30:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 8:
# Nombre: Home
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/BD77BD51-C1A6-49BB-82EC-1BA15127E2F5/
# ID: BD77BD51-C1A6-49BB-82EC-1BA15127E2F5
#
# Eventos:
#
# Evento 1:
# Título: Sleep
# Inicio: 2025-01-19 02:00:00-05:00
# Fin: 2025-01-19 11:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 2:
# Título: Start day
# Inicio: 2025-01-19 11:00:00-05:00
# Fin: 2025-01-19 12:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Evento 3:
# Título: Ferney
# Inicio: 2025-01-19 20:00:00-05:00
# Fin: 2025-01-19 21:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# Calendario 9:
# Nombre: Personal projects
# URL: https://p47-caldav.icloud.com:443/17831883407/calendars/D5392B53-B0D5-4747-AFE5-E4625293BCD4/
# ID: D5392B53-B0D5-4747-AFE5-E4625293BCD4
#
# Eventos:
#
# Evento 1:
# Título: App calendar
# Inicio: 2025-01-20 15:00:00-05:00
# Fin: 2025-01-20 16:00:00-05:00
# Ubicación: Sin ubicación
# Descripción: Sin descripción
#
# === FIN DEL REPORTE ===
